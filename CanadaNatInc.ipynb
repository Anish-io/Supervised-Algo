# %% [markdown]
# Linear Regression(Canada Nat Income):

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#       4 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
df=pd.read_csv("C:\\Users\\anish_6m\\Downloads\\canada_per_capita_income.csv")
print(df)
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
plt.scatter(df["year"],df["per capita income (US$)"],color='red',marker='o')
plt.plot(df.year,reg.predict(df[["year"]]),color='blue')
plt.xlabel("Year")
plt.ylabel("Per Capita Income (US$)")
plt.show()

# %%
reg=LinearRegression()
reg.fit(df[["year"]],df[["per capita income (US$)"]])
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 reg.predict([[2020]])
#
# NameError: name 'reg' is not defined

# %%
#Co-Efficient of the Prediction
reg.coef_
# Out:
# array([[828.46507522]])

# %%
#Intercept of the Prediction
reg.intercept_
# Out:
# array([-1632210.75785546])

# %%
#Formula Cross-Check
#y=m*x+b
y=828.46507522*2020+(-1632210.75785546)
print(y)
# Out:
# 41288.69408894004

# %%
import pickle  #pickle module is used for saving the model in a file format

# %%
with open("CanandaNatInc.pxl","wb") as f:
    pickle.dump(reg,f)

# %%
with open("CanandaNatInc.pxl","rb") as f:
    reg =pickle.load(f)

# %%
reg.predict([[2026]])
# Out:
# C:\Users\anish_6m\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[46259.48454575]])

# %%
import joblib # for more efficient and more numpy array handling
joblib.dump(reg,"CanadaNatInc_joblib")
# Out:
# ['CanadaNatInc_joblib']

# %%
reg=joblib.load("CanadaNatInc_joblib")

# %%
reg.predict([[2024]])
# Out:
# C:\Users\anish_6m\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[44602.55439531]])

# %%
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
X=df[["year"]]
Y=df[["per capita income (US$)"]]
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Testing_data=reg.predict(X_test)
print(Testing_data)
# Out:
# [[22279.39968245]
#  [32061.10983855]
#  [21464.25716944]
#  [35321.67989059]
#  [19833.97214342]
#  [29615.68229953]
#  [10052.26198731]
#  [15758.25957838]
#  [ 3531.12188324]
#  [20649.11465643]]
